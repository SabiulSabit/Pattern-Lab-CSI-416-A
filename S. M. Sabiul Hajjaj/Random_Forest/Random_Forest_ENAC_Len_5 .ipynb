# %%
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pos_5289 = "/content/drive/My Drive/npy File All/A.thaliana5289_pos.fasta-ENAC-Len-5.npy"
neg_5289 = "/content/drive/My Drive/npy File All/A.thaliana5289_neg.fasta-ENAC-Len-5.npy"
pos_1000 = "/content/drive/My Drive/npy File All/A.thaliana1000indep_pos-ENAC-Len-5.npy"
neg_1000 = "/content/drive/My Drive/npy File All/A.thaliana1000indep_neg.fasta-ENAC-5.npy"


x_train_pos = np.load(pos_5289) 
x_train_neg = np.load(neg_5289) 
x_test_pos = np.load(pos_1000) 
x_test_neg = np.load(neg_1000) 

y_train_pos = np.tile(1, 5289) 
y_train_neg = np.tile(0, 5289) 
y_test_pos = np.tile(1, 1000) 
y_test_neg = np.tile(0, 1000)

# %%
x_training = np.concatenate((x_train_pos, x_train_neg), axis = 0)
y_training = np.concatenate((y_train_pos, y_train_neg))

x_test = np.concatenate((x_test_pos, x_test_neg), axis = 0)
y_test = np.concatenate((y_test_pos, y_test_neg))

# %%
X_train, X_val, Y_train, Y_val = train_test_split(x_training, y_training, test_size=0.25, random_state=0)

# %%
seed = 100
np.random.seed(seed) 

kf = KFold(n_splits=5, random_state=seed,shuffle=True)

# %%
test_avg_acc_list = []
j = 1
for c in range(1,452,50):
  RFC = RandomForestClassifier(n_estimators=c,max_depth=None)
  val_accuracy_list = []
  train_accuracy_list = []
  test_acc_list = []
  test_avg = 0
  for train_index, val_index in kf.split(x_training):
    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    
    RFC.fit(X_train, y_train)

    y_val_pred = RFC.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_accuracy_list.append(val_accuracy)

    y_train_pred = RFC.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_list.append(train_accuracy)

    y_test_pred = RFC.predict(x_test)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_acc_list.append(test_accuracy)
    test_avg = test_avg + test_accuracy
  test_avg = test_avg/5
  print(f"Epoch {j}/{10} for C = {c}")
  j=j+1
  for i in range(0, len(train_accuracy_list)):
    print("Train Accuracy : ", train_accuracy_list[i], "\tValidation Accuracy : ", val_accuracy_list[i],"\tTest Accuracy ",test_acc_list[i])
  print("Avg Test Accuracy:",test_avg)
# Out:
# Epoch 1/10 for C = 1
# Train Accuracy :  0.9092413141101394 	Validation Accuracy :  0.7731568998109641 	Test Accuracy  0.595
# Train Accuracy :  0.9197589222406051 	Validation Accuracy :  0.7844990548204159 	Test Accuracy  0.574
# Train Accuracy :  0.9151500827227605 	Validation Accuracy :  0.7641776937618148 	Test Accuracy  0.672
# Train Accuracy :  0.9072432943400686 	Validation Accuracy :  0.7635933806146572 	Test Accuracy  0.5375
# Train Accuracy :  0.9187049509630155 	Validation Accuracy :  0.7858156028368795 	Test Accuracy  0.5955
# Avg Test Accuracy: 0.5948
# Epoch 2/10 for C = 51
# Train Accuracy :  1.0 	Validation Accuracy :  0.9593572778827977 	Test Accuracy  0.71
# Train Accuracy :  1.0 	Validation Accuracy :  0.9650283553875236 	Test Accuracy  0.6905
# Train Accuracy :  1.0 	Validation Accuracy :  0.9655009451795841 	Test Accuracy  0.711
# Train Accuracy :  1.0 	Validation Accuracy :  0.956501182033097 	Test Accuracy  0.7325
# Train Accuracy :  1.0 	Validation Accuracy :  0.9654846335697399 	Test Accuracy  0.7035
# Avg Test Accuracy: 0.7095
# Epoch 3/10 for C = 101
# Train Accuracy :  1.0 	Validation Accuracy :  0.9655009451795841 	Test Accuracy  0.7135
# Train Accuracy :  1.0 	Validation Accuracy :  0.9636105860113422 	Test Accuracy  0.7375
# Train Accuracy :  1.0 	Validation Accuracy :  0.9669187145557656 	Test Accuracy  0.722
# Train Accuracy :  1.0 	Validation Accuracy :  0.9602836879432625 	Test Accuracy  0.7395
# Train Accuracy :  1.0 	Validation Accuracy :  0.966903073286052 	Test Accuracy  0.707
# Avg Test Accuracy: 0.7239
# Epoch 4/10 for C = 151
# Train Accuracy :  1.0 	Validation Accuracy :  0.9688090737240076 	Test Accuracy  0.709
# Train Accuracy :  1.0 	Validation Accuracy :  0.9688090737240076 	Test Accuracy  0.7275
# Train Accuracy :  1.0 	Validation Accuracy :  0.967391304347826 	Test Accuracy  0.726
# Train Accuracy :  1.0 	Validation Accuracy :  0.9659574468085106 	Test Accuracy  0.74
# Train Accuracy :  1.0 	Validation Accuracy :  0.9702127659574468 	Test Accuracy  0.727
# Avg Test Accuracy: 0.7259
# Epoch 5/10 for C = 201
# Train Accuracy :  1.0 	Validation Accuracy :  0.9678638941398866 	Test Accuracy  0.7365
# Train Accuracy :  1.0 	Validation Accuracy :  0.9716446124763705 	Test Accuracy  0.737
# Train Accuracy :  1.0 	Validation Accuracy :  0.9725897920604915 	Test Accuracy  0.7365
# Train Accuracy :  1.0 	Validation Accuracy :  0.9725768321513002 	Test Accuracy  0.7405
# Train Accuracy :  1.0 	Validation Accuracy :  0.9702127659574468 	Test Accuracy  0.728
# Avg Test Accuracy: 0.7356999999999999
# Epoch 6/10 for C = 251
# Train Accuracy :  1.0 	Validation Accuracy :  0.9716446124763705 	Test Accuracy  0.728
# Train Accuracy :  1.0 	Validation Accuracy :  0.9706994328922496 	Test Accuracy  0.723
# Train Accuracy :  1.0 	Validation Accuracy :  0.974007561436673 	Test Accuracy  0.733
# Train Accuracy :  1.0 	Validation Accuracy :  0.966903073286052 	Test Accuracy  0.749
# Train Accuracy :  1.0 	Validation Accuracy :  0.9735224586288416 	Test Accuracy  0.7225
# Avg Test Accuracy: 0.7311000000000001
# Epoch 7/10 for C = 301
# Train Accuracy :  1.0 	Validation Accuracy :  0.974007561436673 	Test Accuracy  0.7325
# Train Accuracy :  1.0 	Validation Accuracy :  0.9725897920604915 	Test Accuracy  0.733
# Train Accuracy :  1.0 	Validation Accuracy :  0.974007561436673 	Test Accuracy  0.73
# Train Accuracy :  1.0 	Validation Accuracy :  0.9706855791962175 	Test Accuracy  0.731
# Train Accuracy :  1.0 	Validation Accuracy :  0.9711583924349881 	Test Accuracy  0.723
# Avg Test Accuracy: 0.7299
# Epoch 8/10 for C = 351
# Train Accuracy :  1.0 	Validation Accuracy :  0.970226843100189 	Test Accuracy  0.733
# Train Accuracy :  1.0 	Validation Accuracy :  0.973062381852552 	Test Accuracy  0.7395
# Train Accuracy :  1.0 	Validation Accuracy :  0.970226843100189 	Test Accuracy  0.739
# Train Accuracy :  1.0 	Validation Accuracy :  0.9678486997635933 	Test Accuracy  0.724
# Train Accuracy :  1.0 	Validation Accuracy :  0.9706855791962175 	Test Accuracy  0.7305
# Avg Test Accuracy: 0.7332000000000001
# Epoch 9/10 for C = 401
# Train Accuracy :  1.0 	Validation Accuracy :  0.969281663516068 	Test Accuracy  0.73
# Train Accuracy :  1.0 	Validation Accuracy :  0.9716446124763705 	Test Accuracy  0.7385
# Train Accuracy :  1.0 	Validation Accuracy :  0.970226843100189 	Test Accuracy  0.7195
# Train Accuracy :  1.0 	Validation Accuracy :  0.9706855791962175 	Test Accuracy  0.743
# Train Accuracy :  1.0 	Validation Accuracy :  0.9730496453900709 	Test Accuracy  0.744
# Avg Test Accuracy: 0.735
# Epoch 10/10 for C = 451
# Train Accuracy :  1.0 	Validation Accuracy :  0.9716446124763705 	Test Accuracy  0.726
# Train Accuracy :  1.0 	Validation Accuracy :  0.973062381852552 	Test Accuracy  0.74
# Train Accuracy :  1.0 	Validation Accuracy :  0.969281663516068 	Test Accuracy  0.732
# Train Accuracy :  1.0 	Validation Accuracy :  0.9702127659574468 	Test Accuracy  0.72
# Train Accuracy :  1.0 	Validation Accuracy :  0.9725768321513002 	Test Accuracy  0.7355
# Avg Test Accuracy: 0.7307

# %%
test_avg_acc_list = []
j = 1
for c in range(195,205,1):
  RFC = RandomForestClassifier(n_estimators=c,max_depth=None)
  val_accuracy_list = []
  train_accuracy_list = []
  test_acc_list = []
  test_avg = 0
  for train_index, val_index in kf.split(x_training):
    #print("train = ",train_index,"Val =",val_index)
    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    
    RFC.fit(X_train, y_train)

    y_val_pred = RFC.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_accuracy_list.append(val_accuracy)

    y_train_pred = RFC.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_list.append(train_accuracy)

    y_test_pred = RFC.predict(x_test)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_acc_list.append(test_accuracy)
    test_avg = test_avg + test_accuracy
  test_avg = test_avg/5
  print(f"Epoch {j}/{10} for C = {c}")
  j=j+1
  for i in range(0, len(train_accuracy_list)):
    print("Train Accuracy : ", train_accuracy_list[i], "\tValidation Accuracy : ", val_accuracy_list[i],"\tTest Accuracy ",test_acc_list[i])
  print("Avg Test Accuracy:",test_avg)
# Out:
# Epoch 1/10 for C = 195
# Train Accuracy :  1.0 	Validation Accuracy :  0.9688090737240076 	Test Accuracy  0.7015
# Train Accuracy :  1.0 	Validation Accuracy :  0.9706994328922496 	Test Accuracy  0.741
# Train Accuracy :  1.0 	Validation Accuracy :  0.9669187145557656 	Test Accuracy  0.71
# Train Accuracy :  1.0 	Validation Accuracy :  0.968321513002364 	Test Accuracy  0.7365
# Train Accuracy :  1.0 	Validation Accuracy :  0.9702127659574468 	Test Accuracy  0.735
# Avg Test Accuracy: 0.7247999999999999
# Epoch 2/10 for C = 196
# Train Accuracy :  1.0 	Validation Accuracy :  0.969281663516068 	Test Accuracy  0.7245
# Train Accuracy :  1.0 	Validation Accuracy :  0.970226843100189 	Test Accuracy  0.7235
# Train Accuracy :  1.0 	Validation Accuracy :  0.9688090737240076 	Test Accuracy  0.732
# Train Accuracy :  1.0 	Validation Accuracy :  0.9659574468085106 	Test Accuracy  0.734
# Train Accuracy :  1.0 	Validation Accuracy :  0.9702127659574468 	Test Accuracy  0.709
# Avg Test Accuracy: 0.7245999999999999
# Epoch 3/10 for C = 197
# Train Accuracy :  1.0 	Validation Accuracy :  0.972117202268431 	Test Accuracy  0.732
# Train Accuracy :  1.0 	Validation Accuracy :  0.969281663516068 	Test Accuracy  0.734
# Train Accuracy :  1.0 	Validation Accuracy :  0.968336483931947 	Test Accuracy  0.7105
# Train Accuracy :  1.0 	Validation Accuracy :  0.9640661938534278 	Test Accuracy  0.741
# Train Accuracy :  1.0 	Validation Accuracy :  0.9697399527186761 	Test Accuracy  0.7245
# Avg Test Accuracy: 0.7283999999999999
# Epoch 4/10 for C = 198
# Train Accuracy :  1.0 	Validation Accuracy :  0.970226843100189 	Test Accuracy  0.718
# Train Accuracy :  1.0 	Validation Accuracy :  0.973062381852552 	Test Accuracy  0.7335
# Train Accuracy :  1.0 	Validation Accuracy :  0.968336483931947 	Test Accuracy  0.735
# Train Accuracy :  1.0 	Validation Accuracy :  0.9687943262411347 	Test Accuracy  0.7255
# Train Accuracy :  1.0 	Validation Accuracy :  0.9692671394799054 	Test Accuracy  0.728
# Avg Test Accuracy: 0.728
# Epoch 5/10 for C = 199
# Train Accuracy :  1.0 	Validation Accuracy :  0.9744801512287334 	Test Accuracy  0.732
# Train Accuracy :  1.0 	Validation Accuracy :  0.972117202268431 	Test Accuracy  0.739
# Train Accuracy :  1.0 	Validation Accuracy :  0.9678638941398866 	Test Accuracy  0.726
# Train Accuracy :  1.0 	Validation Accuracy :  0.9621749408983451 	Test Accuracy  0.729
# Train Accuracy :  1.0 	Validation Accuracy :  0.9687943262411347 	Test Accuracy  0.738
# Avg Test Accuracy: 0.7328
# Epoch 6/10 for C = 200
# Train Accuracy :  1.0 	Validation Accuracy :  0.9697542533081286 	Test Accuracy  0.722
# Train Accuracy :  1.0 	Validation Accuracy :  0.9706994328922496 	Test Accuracy  0.7215
# Train Accuracy :  1.0 	Validation Accuracy :  0.969281663516068 	Test Accuracy  0.7225
# Train Accuracy :  1.0 	Validation Accuracy :  0.968321513002364 	Test Accuracy  0.7265
# Train Accuracy :  1.0 	Validation Accuracy :  0.9673758865248226 	Test Accuracy  0.7245
# Avg Test Accuracy: 0.7234
# Epoch 7/10 for C = 201
# Train Accuracy :  1.0 	Validation Accuracy :  0.973062381852552 	Test Accuracy  0.7435
# Train Accuracy :  1.0 	Validation Accuracy :  0.9664461247637051 	Test Accuracy  0.7385
# Train Accuracy :  1.0 	Validation Accuracy :  0.968336483931947 	Test Accuracy  0.711
# Train Accuracy :  1.0 	Validation Accuracy :  0.9664302600472813 	Test Accuracy  0.7375
# Train Accuracy :  1.0 	Validation Accuracy :  0.9706855791962175 	Test Accuracy  0.7335
# Avg Test Accuracy: 0.7328000000000001
# Epoch 8/10 for C = 202
# Train Accuracy :  1.0 	Validation Accuracy :  0.973062381852552 	Test Accuracy  0.724
# Train Accuracy :  1.0 	Validation Accuracy :  0.9678638941398866 	Test Accuracy  0.735
# Train Accuracy :  1.0 	Validation Accuracy :  0.968336483931947 	Test Accuracy  0.7325
# Train Accuracy :  1.0 	Validation Accuracy :  0.9721040189125295 	Test Accuracy  0.7425
# Train Accuracy :  1.0 	Validation Accuracy :  0.9687943262411347 	Test Accuracy  0.731
# Avg Test Accuracy: 0.733
# Epoch 9/10 for C = 203
# Train Accuracy :  1.0 	Validation Accuracy :  0.9716446124763705 	Test Accuracy  0.7175
# Train Accuracy :  1.0 	Validation Accuracy :  0.9706994328922496 	Test Accuracy  0.7245
# Train Accuracy :  1.0 	Validation Accuracy :  0.9678638941398866 	Test Accuracy  0.709
# Train Accuracy :  1.0 	Validation Accuracy :  0.9664302600472813 	Test Accuracy  0.7365
# Train Accuracy :  1.0 	Validation Accuracy :  0.9692671394799054 	Test Accuracy  0.724
# Avg Test Accuracy: 0.7223
# Epoch 10/10 for C = 204
# Train Accuracy :  1.0 	Validation Accuracy :  0.972117202268431 	Test Accuracy  0.7135
# Train Accuracy :  1.0 	Validation Accuracy :  0.9716446124763705 	Test Accuracy  0.714
# Train Accuracy :  1.0 	Validation Accuracy :  0.968336483931947 	Test Accuracy  0.7365
# Train Accuracy :  1.0 	Validation Accuracy :  0.9697399527186761 	Test Accuracy  0.7165
# Train Accuracy :  1.0 	Validation Accuracy :  0.9706855791962175 	Test Accuracy  0.7445
# Avg Test Accuracy: 0.725

# %%
test_avg_acc_list = []
j = 1
for c in range(1,101,10):
  RFC = RandomForestClassifier(n_estimators=500,max_depth=c)
  val_accuracy_list = []
  train_accuracy_list = []
  test_acc_list = []
  test_avg = 0
  for train_index, val_index in kf.split(x_training):
    #print("train = ",train_index,"Val =",val_index)
    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    
    RFC.fit(X_train, y_train)

    y_val_pred = RFC.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_accuracy_list.append(val_accuracy)

    y_train_pred = RFC.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_list.append(train_accuracy)

    y_test_pred = RFC.predict(x_test)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_acc_list.append(test_accuracy)
    test_avg = test_avg + test_accuracy
  test_avg = test_avg/5
  print(f"Epoch {j}/{10} for depth = {c}")
  j=j+1
  for i in range(0, len(train_accuracy_list)):
    print("Train Accuracy : ", train_accuracy_list[i], "\tValidation Accuracy : ", val_accuracy_list[i],"\tTest Accuracy ",test_acc_list[i])
  print("Avg Test Accuracy:",test_avg)
# Out:
# Epoch 1/10 for depth = 1
# Train Accuracy :  0.7751122666036399 	Validation Accuracy :  0.7603969754253308 	Test Accuracy  0.6215
# Train Accuracy :  0.7606948711888443 	Validation Accuracy :  0.7589792060491494 	Test Accuracy  0.6215
# Train Accuracy :  0.7653037107066887 	Validation Accuracy :  0.7589792060491494 	Test Accuracy  0.619
# Train Accuracy :  0.7753751624719367 	Validation Accuracy :  0.7739952718676123 	Test Accuracy  0.62
# Train Accuracy :  0.7695852534562212 	Validation Accuracy :  0.7730496453900709 	Test Accuracy  0.6255
# Avg Test Accuracy: 0.6214999999999999
# Epoch 2/10 for depth = 11
# Train Accuracy :  0.9990545970219806 	Validation Accuracy :  0.9659735349716446 	Test Accuracy  0.726
# Train Accuracy :  0.9990545970219806 	Validation Accuracy :  0.9650283553875236 	Test Accuracy  0.7345
# Train Accuracy :  0.9991727723942331 	Validation Accuracy :  0.9645557655954632 	Test Accuracy  0.7265
# Train Accuracy :  0.999291031549096 	Validation Accuracy :  0.9626477541371158 	Test Accuracy  0.7305
# Train Accuracy :  0.999291031549096 	Validation Accuracy :  0.9645390070921985 	Test Accuracy  0.7235
# Avg Test Accuracy: 0.7282000000000001
# Epoch 3/10 for depth = 21
# Train Accuracy :  1.0 	Validation Accuracy :  0.974007561436673 	Test Accuracy  0.7355
# Train Accuracy :  1.0 	Validation Accuracy :  0.9716446124763705 	Test Accuracy  0.735
# Train Accuracy :  1.0 	Validation Accuracy :  0.970226843100189 	Test Accuracy  0.7235
# Train Accuracy :  1.0 	Validation Accuracy :  0.9716312056737588 	Test Accuracy  0.733
# Train Accuracy :  1.0 	Validation Accuracy :  0.9730496453900709 	Test Accuracy  0.722
# Avg Test Accuracy: 0.7298
# Epoch 4/10 for depth = 31
# Train Accuracy :  1.0 	Validation Accuracy :  0.9716446124763705 	Test Accuracy  0.7195
# Train Accuracy :  1.0 	Validation Accuracy :  0.972117202268431 	Test Accuracy  0.73
# Train Accuracy :  1.0 	Validation Accuracy :  0.968336483931947 	Test Accuracy  0.7275
# Train Accuracy :  1.0 	Validation Accuracy :  0.9697399527186761 	Test Accuracy  0.726
# Train Accuracy :  1.0 	Validation Accuracy :  0.9706855791962175 	Test Accuracy  0.738
# Avg Test Accuracy: 0.7282
# Epoch 5/10 for depth = 41
# Train Accuracy :  1.0 	Validation Accuracy :  0.9716446124763705 	Test Accuracy  0.7285
# Train Accuracy :  1.0 	Validation Accuracy :  0.972117202268431 	Test Accuracy  0.7475
# Train Accuracy :  1.0 	Validation Accuracy :  0.9744801512287334 	Test Accuracy  0.7295
# Train Accuracy :  1.0 	Validation Accuracy :  0.9711583924349881 	Test Accuracy  0.7275
# Train Accuracy :  1.0 	Validation Accuracy :  0.9721040189125295 	Test Accuracy  0.731
# Avg Test Accuracy: 0.7327999999999999
# Epoch 6/10 for depth = 51
# Train Accuracy :  1.0 	Validation Accuracy :  0.972117202268431 	Test Accuracy  0.7355
# Train Accuracy :  1.0 	Validation Accuracy :  0.9697542533081286 	Test Accuracy  0.736
# Train Accuracy :  1.0 	Validation Accuracy :  0.97117202268431 	Test Accuracy  0.7365
# Train Accuracy :  1.0 	Validation Accuracy :  0.9687943262411347 	Test Accuracy  0.7395
# Train Accuracy :  1.0 	Validation Accuracy :  0.9697399527186761 	Test Accuracy  0.7345
# Avg Test Accuracy: 0.7364
# Epoch 7/10 for depth = 61
# Train Accuracy :  1.0 	Validation Accuracy :  0.97117202268431 	Test Accuracy  0.721
# Train Accuracy :  1.0 	Validation Accuracy :  0.9697542533081286 	Test Accuracy  0.7405
# Train Accuracy :  1.0 	Validation Accuracy :  0.969281663516068 	Test Accuracy  0.7235
# Train Accuracy :  1.0 	Validation Accuracy :  0.9706855791962175 	Test Accuracy  0.741
# Train Accuracy :  1.0 	Validation Accuracy :  0.9711583924349881 	Test Accuracy  0.7325
# Avg Test Accuracy: 0.7317
# Epoch 8/10 for depth = 71
# Train Accuracy :  1.0 	Validation Accuracy :  0.9735349716446124 	Test Accuracy  0.7235
# Train Accuracy :  1.0 	Validation Accuracy :  0.9735349716446124 	Test Accuracy  0.7445
# Train Accuracy :  1.0 	Validation Accuracy :  0.97117202268431 	Test Accuracy  0.734
# Train Accuracy :  1.0 	Validation Accuracy :  0.9711583924349881 	Test Accuracy  0.727
# Train Accuracy :  1.0 	Validation Accuracy :  0.9725768321513002 	Test Accuracy  0.7365
# Avg Test Accuracy: 0.7331
# Epoch 9/10 for depth = 81
# Train Accuracy :  1.0 	Validation Accuracy :  0.9706994328922496 	Test Accuracy  0.7325
# Train Accuracy :  1.0 	Validation Accuracy :  0.9716446124763705 	Test Accuracy  0.727
# Train Accuracy :  1.0 	Validation Accuracy :  0.970226843100189 	Test Accuracy  0.734
# Train Accuracy :  1.0 	Validation Accuracy :  0.9692671394799054 	Test Accuracy  0.74
# Train Accuracy :  1.0 	Validation Accuracy :  0.966903073286052 	Test Accuracy  0.7345
# Avg Test Accuracy: 0.7336000000000001
# Epoch 10/10 for depth = 91
# Train Accuracy :  1.0 	Validation Accuracy :  0.97117202268431 	Test Accuracy  0.7235
# Train Accuracy :  1.0 	Validation Accuracy :  0.9697542533081286 	Test Accuracy  0.7295
# Train Accuracy :  1.0 	Validation Accuracy :  0.9716446124763705 	Test Accuracy  0.734
# Train Accuracy :  1.0 	Validation Accuracy :  0.9716312056737588 	Test Accuracy  0.7295
# Train Accuracy :  1.0 	Validation Accuracy :  0.9716312056737588 	Test Accuracy  0.749
# Avg Test Accuracy: 0.7331000000000001
